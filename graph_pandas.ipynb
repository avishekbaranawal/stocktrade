# %% [markdown]
# graph with pandas

# %%
import plotly
import pandas as pd
import numpy as np 
import seaborn as sns
import plotly.express as px

import matplotlib

# %matplotlib inline

data = pd.read_csv('https://raw.githubusercontent.com/FBosler/AdvancedPlotting/master/combined_set.csv')
data['Mean Log GDP per capita']  = data.groupby('Year')['Log GDP per capita'].transform(
    pd.qcut,
    q=5,
    labels=(['Lowest','Low','Medium','High','Highest'])
)
np.exp(data[data['Year']==2018]['Log GDP per capita']).plot(
    kind='hist'
)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\urllib\request.py:1350, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=1348'>1349</a> try:
# -> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=1349'>1350</a>     h.request(req.get_method(), req.selector, req.data, headers,
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=1350'>1351</a>               encode_chunked=req.has_header('Transfer-encoding'))
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=1351'>1352</a> except OSError as err: # timeout error
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\http\client.py:1240, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=1238'>1239</a> """Send a complete request to the server."""
# -> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=1239'>1240</a> self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\http\client.py:1286, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=1284'>1285</a>     body = _encode(body, 'body')
# -> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=1285'>1286</a> self.endheaders(body, encode_chunked=encode_chunked)
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\http\client.py:1235, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=1233'>1234</a>     raise CannotSendHeader()
# -> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=1234'>1235</a> self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\http\client.py:1006, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=1004'>1005</a> del self._buffer[:]
# -> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=1005'>1006</a> self.send(msg)
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=1007'>1008</a> if message_body is not None:
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=1008'>1009</a>
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=1009'>1010</a>     # create a consistent interface to message_body
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\http\client.py:946, in HTTPConnection.send(self, data)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=944'>945</a> if self.auto_open:
# --> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=945'>946</a>     self.connect()
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=946'>947</a> else:
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\http\client.py:1402, in HTTPSConnection.connect(self)
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=1399'>1400</a> "Connect to a host on a given (SSL) port."
# -> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=1401'>1402</a> super().connect()
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=1403'>1404</a> if self._tunnel_host:
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\http\client.py:917, in HTTPConnection.connect(self)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=915'>916</a> """Connect to the host and port specified in __init__."""
# --> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=916'>917</a> self.sock = self._create_connection(
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=917'>918</a>     (self.host,self.port), self.timeout, self.source_address)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/http/client.py?line=918'>919</a> self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\socket.py:787, in create_connection(address, timeout, source_address)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/socket.py?line=785'>786</a> err = None
# --> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/socket.py?line=786'>787</a> for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/socket.py?line=787'>788</a>     af, socktype, proto, canonname, sa = res
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\socket.py:918, in getaddrinfo(host, port, family, type, proto, flags)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/socket.py?line=916'>917</a> addrlist = []
# --> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/socket.py?line=917'>918</a> for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/socket.py?line=918'>919</a>     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# c:\Users\avish\stocktrade\graph_pandas.ipynb Cell 2' in <cell line: 11>()
#       <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000001?line=6'>7</a> import matplotlib
#       <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000001?line=8'>9</a> get_ipython().run_line_magic('matplotlib', 'inline')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000001?line=10'>11</a> data = pd.read_csv('https://raw.githubusercontent.com/FBosler/AdvancedPlotting/master/combined_set.csv')
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000001?line=11'>12</a> data['Mean Log GDP per capita']  = data.groupby('Year')['Log GDP per capita'].transform(
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000001?line=12'>13</a>     pd.qcut,
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000001?line=13'>14</a>     q=5,
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000001?line=14'>15</a>     labels=(['Lowest','Low','Medium','High','Highest'])
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000001?line=15'>16</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000001?line=16'>17</a> np.exp(data[data['Year']==2018]['Log GDP per capita']).plot(
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000001?line=17'>18</a>     kind='hist'
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000001?line=18'>19</a> )
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\parsers.py:605, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=599'>600</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=600'>601</a>     dialect, delimiter, delim_whitespace, engine, sep, defaults={"delimiter": ","}
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=601'>602</a> )
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=602'>603</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=604'>605</a> return _read(filepath_or_buffer, kwds)
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\parsers.py:457, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=453'>454</a> _validate_names(kwds.get("names", None))
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=455'>456</a> # Create the parser.
# --> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=456'>457</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=458'>459</a> if chunksize or iterator:
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=459'>460</a>     return parser
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\parsers.py:814, in TextFileReader.__init__(self, f, engine, **kwds)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=810'>811</a> if "has_index_names" in kwds:
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=811'>812</a>     self.options["has_index_names"] = kwds["has_index_names"]
# --> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=813'>814</a> self._engine = self._make_engine(self.engine)
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\parsers.py:1045, in TextFileReader._make_engine(self, engine)
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1040'>1041</a>     raise ValueError(
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1041'>1042</a>         f"Unknown engine: {engine} (valid options are {mapping.keys()})"
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1042'>1043</a>     )
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1043'>1044</a> # error: Too many arguments for "ParserBase"
# -> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1044'>1045</a> return mapping[engine](self.f, **self.options)
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\parsers.py:1862, in CParserWrapper.__init__(self, src, **kwds)
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1858'>1859</a> kwds["usecols"] = self.usecols
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1860'>1861</a> # open handles
# -> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1861'>1862</a> self._open_handles(src, kwds)
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1862'>1863</a> assert self.handles is not None
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1863'>1864</a> for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\parsers.py:1357, in ParserBase._open_handles(self, src, kwds)
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1352'>1353</a> def _open_handles(self, src: FilePathOrBuffer, kwds: Dict[str, Any]) -> None:
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1353'>1354</a>     """
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1354'>1355</a>     Let the readers open IOHanldes after they are done with their potential raises.
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1355'>1356</a>     """
# -> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1356'>1357</a>     self.handles = get_handle(
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1357'>1358</a>         src,
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1358'>1359</a>         "r",
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1359'>1360</a>         encoding=kwds.get("encoding", None),
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1360'>1361</a>         compression=kwds.get("compression", None),
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1361'>1362</a>         memory_map=kwds.get("memory_map", False),
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1362'>1363</a>         storage_options=kwds.get("storage_options", None),
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/parsers.py?line=1363'>1364</a>     )
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\common.py:558, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=554'>555</a>     mode += "b"
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=556'>557</a> # open URLs
# --> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=557'>558</a> ioargs = _get_filepath_or_buffer(
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=558'>559</a>     path_or_buf,
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=559'>560</a>     encoding=encoding,
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=560'>561</a>     compression=compression,
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=561'>562</a>     mode=mode,
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=562'>563</a>     storage_options=storage_options,
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=563'>564</a> )
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=565'>566</a> handle = ioargs.filepath_or_buffer
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=566'>567</a> handles: List[Buffer]
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\common.py:288, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=283'>284</a> if storage_options:
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=284'>285</a>     raise ValueError(
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=285'>286</a>         "storage_options passed with file object or non-fsspec file path"
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=286'>287</a>     )
# --> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=287'>288</a> req = urlopen(filepath_or_buffer)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=288'>289</a> content_encoding = req.headers.get("Content-Encoding", None)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=289'>290</a> if content_encoding == "gzip":
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=290'>291</a>     # Override compression based on Content-Encoding header
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\common.py:194, in urlopen(*args, **kwargs)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=187'>188</a> """
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=188'>189</a> Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=189'>190</a> the stdlib.
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=190'>191</a> """
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=191'>192</a> import urllib.request
# --> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/io/common.py?line=193'>194</a> return urllib.request.urlopen(*args, **kwargs)
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\urllib\request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=219'>220</a> else:
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=220'>221</a>     opener = _opener
# --> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=221'>222</a> return opener.open(url, data, timeout)
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=521'>522</a>     req = meth(req)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=523'>524</a> sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=524'>525</a> response = self._open(req, data)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=526'>527</a> # post-process response
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=527'>528</a> meth_name = protocol+"_response"
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\urllib\request.py:542, in OpenerDirector._open(self, req, data)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=538'>539</a>     return result
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=540'>541</a> protocol = req.type
# --> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=541'>542</a> result = self._call_chain(self.handle_open, protocol, protocol +
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=542'>543</a>                           '_open', req)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=543'>544</a> if result:
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=544'>545</a>     return result
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\urllib\request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=499'>500</a> for handler in handlers:
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=500'>501</a>     func = getattr(handler, meth_name)
# --> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=501'>502</a>     result = func(*args)
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=502'>503</a>     if result is not None:
#     <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=503'>504</a>         return result
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\urllib\request.py:1393, in HTTPSHandler.https_open(self, req)
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=1391'>1392</a> def https_open(self, req):
# -> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=1392'>1393</a>     return self.do_open(http.client.HTTPSConnection, req,
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=1393'>1394</a>         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\avish\AppData\Local\Programs\Python\Python38-32\lib\urllib\request.py:1353, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=1349'>1350</a>         h.request(req.get_method(), req.selector, req.data, headers,
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=1350'>1351</a>                   encode_chunked=req.has_header('Transfer-encoding'))
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=1351'>1352</a>     except OSError as err: # timeout error
# -> <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=1352'>1353</a>         raise URLError(err)
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=1353'>1354</a>     r = h.getresponse()
#    <a href='file:///c%3A/Users/avish/AppData/Local/Programs/Python/Python38-32/lib/urllib/request.py?line=1354'>1355</a> except:
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>

# %% [markdown]
# vertical bar

# %%
import plotly
import pandas as pd
import numpy as np 
import seaborn as sns
import plotly.express as px

import matplotlib

# %matplotlib inline

data[
    data['Year'] == 2018
].set_index('Country name')['Life Ladder'].nlargest(15).plot(
    kind='bar',
    figsize=(12,8)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\avish\stocktrade\graph_pandas.ipynb Cell 4' in <cell line: 11>()
#       <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000003?line=6'>7</a> import matplotlib
#       <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000003?line=8'>9</a> get_ipython().run_line_magic('matplotlib', 'inline')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000003?line=10'>11</a> data[
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000003?line=11'>12</a>     data['Year'] == 2018
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000003?line=12'>13</a> ].set_index('Country name')['Life Ladder'].nlargest(15).plot(
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000003?line=13'>14</a>     kind='bar',
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000003?line=14'>15</a>     figsize=(12,8)
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000003?line=15'>16</a> )
#
# NameError: name 'data' is not defined

# %% [markdown]
# horizontal bar

# %%
import plotly
import pandas as pd
import numpy as np 
import seaborn as sns
import plotly.express as px

import matplotlib

# %matplotlib inline

np.exp(data[
    data['Year'] == 2018
].groupby('Continent')['Log GDP per capita']\
    .mean()).sort_values().plot(
        kind='barh',
        figsize=(12,8)

)
# Out:
# <AxesSubplot:ylabel='Continent'>

# %% [markdown]
# scatter

# %%
import plotly
import pandas as pd
import numpy as np 
import seaborn as sns
import plotly.express as px

import matplotlib

# %matplotlib inline

data[['Healthy life expectancy at birth','Gapminder Life Expectancy']].plot(
    kind='scatter',
    x='Healthy life expectancy at birth',
    y='Gapminder Life Expectancy',
    figsize=(12,8)
)
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy at birth', ylabel='Gapminder Life Expectancy'>

# %% [markdown]
# hexbin

# %%
data[data['Year'] == 2018].plot(
    kind='hexbin',
    x='Healthy life expectancy at birth',
    y='Generosity',
    C='Life Ladder',
    gridsize=20,
    figsize=(12,8),
    cmap="Blues", # defaults to greenish
    sharex=False # required to get rid of a bug
)
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy at birth', ylabel='Generosity'>

# %%
#piechart
data[data['Year'] == 2018].groupby(
    ['Continent']
)['Gapminder Population'].sum().plot(
    kind='pie',
    figsize=(12,8),
    cmap="Blues_r", # defaults to orangish
)
# Out:
# <AxesSubplot:ylabel='Gapminder Population'>

# %%
sns.reset_defaults()
sns.set(
    rc={'figure.figsize':(7,5)}, 
    style="white" # nicer layout
)
sns.jointplot(
    x='Log GDP per capita',
    y='Life Ladder',
    data= data,
    kind='scatter' # or 'kde' or 'hex'
)
sns.jointplot(
    x='Log GDP per capita',
    y='Life Ladder',
    data=data,
    kind='scatter' # or 'kde' or 'hex'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\avish\stocktrade\graph_pandas.ipynb Cell 12' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=0'>1</a> sns.reset_defaults()
#       <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=1'>2</a> sns.set(
#       <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=2'>3</a>     rc={'figure.figsize':(7,5)},
#       <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=3'>4</a>     style="white" # nicer layout
#       <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=4'>5</a> )
#       <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=5'>6</a> sns.jointplot(
#       <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=6'>7</a>     x='Log GDP per capita',
#       <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=7'>8</a>     y='Life Ladder',
# ----> <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=8'>9</a>     data= data,
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=9'>10</a>     kind='scatter' # or 'kde' or 'hex'
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=10'>11</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=11'>12</a> sns.jointplot(
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=12'>13</a>     x='Log GDP per capita',
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=13'>14</a>     y='Life Ladder',
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=14'>15</a>     data=data,
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=15'>16</a>     kind='scatter' # or 'kde' or 'hex'
#      <a href='vscode-notebook-cell:/c%3A/Users/avish/stocktrade/graph_pandas.ipynb#ch0000012?line=16'>17</a> )
#
# NameError: name 'data' is not defined
